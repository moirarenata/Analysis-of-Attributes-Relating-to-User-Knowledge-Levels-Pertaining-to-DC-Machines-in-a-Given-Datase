# %% [markdown]
# Title: Analysis of Attributes Relating to User Knowledge Levels In a DC Machine Dataset.
#
# Introduction:
#
# <li> Knowledge modeling is the process of creating a model of knowledge and/or specifications for a particular process, structure, or entity that is interpretable by a computer. In this case, the dataset models knowledge of students in the field of electrical DC machines that convert direct current electrical energy into mechanical energy through various measures such as study time and study repetition through modeling methods. DC machines are used in applications where a wide range of speeds and precise good regulation is a requirement alongside widespread use of AC machines which use alternating current. </li>
#
# <li>Which 2 attributes out of the ones given (within the two groups as determined by their scales) are most correlated with user knowledge level and how are those attributes correlated amongst themselves? </li>
#
# <li>The User Knowledge Modeling Data Set is found in the UCI Machine Learning Repository and was created by Hamdi Tolga Kahraman, Ilhami Colak, and Seref Sagiroglu in 2009. This data set has 258 rows and contains data of the students' knowledge in the field of electrical DC Machines. It has 6 columns, 5 input attributes (quantitative) and 1 target attribute (qualitative). The authors classified the UNS based on the K-nearest neighbour algorithm, also known as k-NN. Descriptions of attributes listed in the table below: </li>
#
# <table style="width:100%">
#   <tr>
#     <th>Attribute</th>
#     <th>Description</th>
#     <th>Example</th>
#   </tr>
#   <tr>
#     <td>STG</td>
#     <td>The degree of study time for goal object materials.</td>
#     <td>0, 0.18, 0.276</td>
#   </tr>
#   <tr>
#     <td>SCG</td>
#     <td>The degree of repetition number of user for goal object materials. </td>
#     <td>0.3, 0.52, 0.259</td>
#   </tr>
#    <tr>
#     <td>STR</td>
#     <td>The degree of study time of user for related objects with goal object. </td>
#     <td>0.12, 0.78, 0.59</td>
#   </tr>
#     <tr>
#     <td>LPR</td>
#     <td>The exam performance of user for related objects with goal object.</td>
#     <td>0.65, 0.81, 0.2</td>
#   </tr>
#     <tr>
#     <td>PEG</td>
#     <td>The exam performance of user for goal objects. </td>
#     <td>0, 0.9, 0.66</td>
#   </tr>
#     <tr>
#     <td>UNS</td>
#     <td>The knowledge level of user. </td>
#     <td>“very_low”, “Low”, “Middle”, “High”</td>
#   </tr>
# </table>

# %% [markdown]
# Preliminary exploratory data analysis:

# %%
library(tidyverse)
library(repr)
library(readxl)
library(GGally)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.3     ✔ dplyr   1.0.2
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
#
# Warning message:
# “package ‘ggplot2’ was built under R version 4.0.1”
# Warning message:
# “package ‘tibble’ was built under R version 4.0.2”
# Warning message:
# “package ‘tidyr’ was built under R version 4.0.2”
# Warning message:
# “package ‘dplyr’ was built under R version 4.0.2”
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Registered S3 method overwritten by 'GGally':
#   method from
#   +.gg   ggplot2

# %% [markdown]
# <li> Demonstrate that the dataset can be read from the web into R: </li>

# %%
user_knowledge_data <- read_excel("data/Data_User_Modeling_Dataset.xls", sheet = 2)
user_knowledge_data
# Out:
# New names:
# * `` -> ...7
# * `` -> ...8
#     STG   SCG   STR  LPR  PEG  UNS      ...7 ...8
# 1   0.00  0.000 0.00 0.00 0.00 very_low NA   NA
# 2   0.08  0.080 0.10 0.24 0.90 High     NA   NA
# 3   0.06  0.060 0.05 0.25 0.33 Low      NA   NA
# 4   0.10  0.100 0.15 0.65 0.30 Middle   NA   NA
# 5   0.08  0.080 0.08 0.98 0.24 Low      NA   NA
# 6   0.09  0.150 0.40 0.10 0.66 Middle   NA   NA
# 7   0.10  0.100 0.43 0.29 0.56 Middle   NA   NA
# 8   0.15  0.020 0.34 0.40 0.01 very_low NA   NA
# 9   0.20  0.140 0.35 0.72 0.25 Low      NA   NA
# 10  0.00  0.000 0.50 0.20 0.85 High     NA   NA
# 11  0.18  0.180 0.55 0.30 0.81 High     NA   NA
# 12  0.06  0.060 0.51 0.41 0.30 Low      NA   NA
# 13  0.10  0.100 0.52 0.78 0.34 Middle   NA   NA
# 14  0.10  0.100 0.70 0.15 0.90 High     NA   NA
# 15  0.20  0.200 0.70 0.30 0.60 Middle   NA   NA
# 16  0.12  0.120 0.75 0.35 0.80 High     NA   NA
# 17  0.05  0.070 0.70 0.01 0.05 very_low NA   NA
# 18  0.10  0.250 0.10 0.08 0.33 Low      NA   NA
# ...

# %% [markdown]
# <li> Clean and wrangle data into a tidy format: </li>

# %%
user_knowledge_data_selected <- select(user_knowledge_data, STG:UNS) 
user_knowledge_data_selected
# Out:
#     STG   SCG   STR  LPR  PEG  UNS
# 1   0.00  0.000 0.00 0.00 0.00 very_low
# 2   0.08  0.080 0.10 0.24 0.90 High
# 3   0.06  0.060 0.05 0.25 0.33 Low
# 4   0.10  0.100 0.15 0.65 0.30 Middle
# 5   0.08  0.080 0.08 0.98 0.24 Low
# 6   0.09  0.150 0.40 0.10 0.66 Middle
# 7   0.10  0.100 0.43 0.29 0.56 Middle
# 8   0.15  0.020 0.34 0.40 0.01 very_low
# 9   0.20  0.140 0.35 0.72 0.25 Low
# 10  0.00  0.000 0.50 0.20 0.85 High
# 11  0.18  0.180 0.55 0.30 0.81 High
# 12  0.06  0.060 0.51 0.41 0.30 Low
# 13  0.10  0.100 0.52 0.78 0.34 Middle
# 14  0.10  0.100 0.70 0.15 0.90 High
# 15  0.20  0.200 0.70 0.30 0.60 Middle
# 16  0.12  0.120 0.75 0.35 0.80 High
# 17  0.05  0.070 0.70 0.01 0.05 very_low
# 18  0.10  0.250 0.10 0.08 0.33 Low
# 19  0.15  0.320 0.05 0.27 0.29 Low
# 20  0.20  0.290 0.25 0.49 0.56 Middle
# 21  0.12  0.280 0.20 0.78 0.20 Low
# 22  0.18  0.300 0.37 0.12 0.66 Middle
# 23  0.10  0.270 0.31 0.29 0.65 Middle
# 24  0.18  0.310 0.32 0.42 0.28 Low
# ...

# %% [markdown]
# <li> Summarize training data based on count of observations and average of each attribute: </li>

# %%
user_knowledge_data_selected_summarize <- user_knowledge_data_selected %>% 
summarize(Count = n(), Average_STG = mean(STG), Average_SCG = mean(SCG), Average_STR = mean(STR), Average_LPR = mean(LPR), Average_PEG = mean(PEG))
user_knowledge_data_selected_summarize
# Out:
#   Count Average_STG Average_SCG Average_STR Average_LPR Average_PEG
# 1 258   0.3711473   0.3556744   0.4680039   0.4327132   0.4585388

# %% [markdown]
# <li> Visualize training data: </li>

# %%
user_knowledge_data_sum_g1 <- user_knowledge_data_selected %>%     
    group_by(UNS) %>% 
    summarize(Sum_STG = sum(STG), Sum_SCG = sum(SCG), Sum_STR = sum(STR))
user_knowledge_data_sum_g1

user_knowledge_data_sum_g2 <- user_knowledge_data_selected %>%     
    group_by(UNS) %>% 
    summarize(Sum_LPR = sum(LPR), Sum_PEG = sum(PEG))
user_knowledge_data_sum_g2
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)
#   UNS      Sum_STG Sum_SCG Sum_STR
# 1 High     26.564  26.661  31.605
# 2 Low      26.655  27.971  35.750
# 3 Middle   35.198  32.377  44.600
# 4 very_low  7.339   4.755   8.790
# `summarise()` ungrouping output (override with `.groups` argument)
#   UNS      Sum_LPR Sum_PEG
# 1 High     31.58   48.670
# 2 Low      41.28   19.723
# 3 Middle   30.17   47.730
# 4 very_low  8.61    2.180

# %%
options(repr.plot.width = 20, repr.plot.height = 10) 

user_knowledge_STG_plot <- ggplot(user_knowledge_data_sum_g1, aes(x = UNS, y = Sum_STG, fill = UNS)) +
    geom_bar(stat = "identity", position = "dodge") +
    labs(x = "User Knowledge Score", y = "STG", fill = "Categories") 
 
user_knowledge_SCG_plot <- ggplot(user_knowledge_data_sum_g1, aes(x = UNS, y = Sum_SCG, fill = UNS)) +
    geom_bar(stat = "identity", position = "dodge") +
    labs(x = "User Knowledge Score", y = "SCG", fill = "Categories")  


user_knowledge_STR_plot <- ggplot(user_knowledge_data_sum_g1, aes(x = UNS, y = Sum_STR, fill = UNS)) +
    geom_bar(stat = "identity", position = "dodge") +
    labs(x = "User Knowledge Score", y = "STR", fill = "Categories") 

require(gridExtra)
grid.arrange(user_knowledge_STG_plot, user_knowledge_SCG_plot, user_knowledge_STR_plot, ncol=3) 

user_knowledge_LPR_plot <- ggplot(user_knowledge_data_sum_g2, aes(x = UNS, y = Sum_LPR, fill = UNS)) +
    geom_bar(stat = "identity", position = "dodge") +
    labs(x = "User Knowledge Score", y = "LPR", fill = "Categories")  


user_knowledge_PEG_plot <- ggplot(user_knowledge_data_sum_g2, aes(x = UNS, y = Sum_PEG, fill = UNS)) +
    geom_bar(stat = "identity", position = "dodge") +
    labs(x = "User Knowledge Score", y = "PEG", fill = "Categories")  

grid.arrange(user_knowledge_LPR_plot, user_knowledge_PEG_plot, ncol=2)
# Out:
# Loading required package: gridExtra
#
#
# Attaching package: ‘gridExtra’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     combine
# plot without title
# plot without title

# %% [markdown]
# Methods:
#
# <li> Explain how you will conduct either your data analysis and which variables/columns you will use: </li>
# 2 grouped bar plots will be created, 1 for STG, SCG, STR and 1 for LPR and PEG graphs as the two groups use a different scale between them, with the sum of the column values on the y-axis and the 4 groups of knowledge levels of users (UNS) on the x-axis. The bar heights of the attributes within the high and middle knowledge level categories will be compared to visually evaluate and select for 1 attribute from each group (1 from STG, SCG, and STR, and 1 from LPR and PEG) that appears most closely linked to the two chosen knowledge levels, in the form of having the highest column heights in those two categories.
# <br><br>
#
#
# <li> Describe at least one way that you will visualize the results: </li>
# A scatter plot to compare these two identified attributes will be made and the correlation strength and direction will be visually evaluated.

# %% [markdown]
# <br><br>
# Expected outcomes and significance:
#
# <li> What do you expect to find? </li>
# We expect to find two attributes that are the closest linked to a middle or high knowledge level and the correlation between the two implicated attributes. <br>
#
# <li> What impact could such findings have? </li>
# The findings could be used to devise learning strategies and frameworks, within the field of electrical DC machines, that would prioritize the selected attributes to maximize user knowledge levels in a given period of time with greater efficiency.
# <br><br>
#
# Future Questions:
# <li> Is the result consistent over similar domains of knowledge and technical fields? </li>
# <li> What factors make the attribute closest linked to user knowledge level as such? </li>
# <li> What attributes are the least linked and why? </li>
# <li> What are the patterns in how different combinations of attributes affect knowledge level? </li>
